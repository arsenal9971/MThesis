# %% [markdown]
# <center><h2>Line detection in recovered EPIs </h2></center>

# %%
# Import the libraries to use
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
import time
# %matplotlib inline

# %%
from PIL import Image

# %% [markdown]
# ### Hough Transform in OpenCV

# %% [markdown]
# #### Each 4

# %%
name4 = '../EPIs_Strips/Inpainted/673_10_102_4_48_8_inpainted.png';
img = cv2.imread(name)

# %%
img4 = cv2.imread(name4)
img_lines4 = cv2.imread(name4)
gray4 = cv2.cvtColor(img_lines4,cv2.COLOR_BGR2GRAY)
edges4 = cv2.Canny(gray4,50,150,apertureSize = 3)
lines4 = cv2.HoughLines(edges4,1,np.pi/180,200)
for line in lines4:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    if (y2-y1)/(x2-x1)!=0:
        cv2.line(img_lines4,(x1,y1),(x2,y2),(0,0,255),2)

# %%
plt.rcParams["figure.figsize"] = [12,9]
plt.imshow(img_lines4)
plt.savefig('../Diagrams/results/Disparity_benchmark/673_10_102_4_48_8_lines.png')
plt.show()

# %% [markdown]
# Now we want to compute the slope of the lines.

# %%
def slope(lines,i):
    line = lines[i]
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    slope = -abs((y2-y1)/(x2-x1))
    return slope,x1,x2,y1,y2

# %%
img = cv2.imread(name4)
i = 0
slopei,x1,x2,y1,y2 = slope(lines4,i);

# %%
slopei
# Out:
# -8

# %%
cv2.line(img4,(x1,y1),(x2,y2),(0,0,255),2);

# %%
plt.imshow(img4)

# %% [markdown]
# #### Each 7

# %%
name7 = '../EPIs_Strips/Inpainted/673_10_102_7_48_8_inpainted.png';
img = cv2.imread(name7)

# %%
img7 = cv2.imread(name7)
img_lines7 = cv2.imread(name7)
gray7 = cv2.cvtColor(img_lines7,cv2.COLOR_BGR2GRAY)
edges7 = cv2.Canny(gray7,50,150,apertureSize = 3)
lines7 = cv2.HoughLines(edges7,1,np.pi/180,200)
for line in lines7:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    if (x2-x1)!=0:
        if (y2-y1)/(x2-x1)!=0:
            cv2.line(img_lines7,(x1,y1),(x2,y2),(0,0,255),2)

# %%
plt.rcParams["figure.figsize"] = [12,9]
plt.imshow(img_lines7)
plt.savefig('../Diagrams/results/Disparity_benchmark/673_10_102_7_48_8_lines.png')
plt.show()

# %% [markdown]
# #### Each 9

# %%
name9 = '../EPIs_Strips/Inpainted/673_10_102_9_48_8_inpainted.png';
img = cv2.imread(name9)

# %%
img9 = cv2.imread(name9)
img_lines9 = cv2.imread(name9)
gray9 = cv2.cvtColor(img_lines9,cv2.COLOR_BGR2GRAY)
edges9 = cv2.Canny(gray9,50,150,apertureSize = 3)
lines9 = cv2.HoughLines(edges9,1,np.pi/180,200)
for line in lines9:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    if (x2-x1)!=0:
        if (y2-y1)/(x2-x1)!=0:
            cv2.line(img_lines9,(x1,y1),(x2,y2),(0,0,255),2)

# %%
plt.rcParams["figure.figsize"] = [12,9]
plt.imshow(img_lines9)
plt.savefig('../Diagrams/results/Disparity_benchmark/673_10_102_9_48_8_lines.png')
plt.show()

# %% [markdown]
# #### Each 12

# %%
name12 = '../EPIs_Strips/Inpainted/673_10_102_12_48_8_inpainted.png';
img = cv2.imread(name12)

# %%
img12 = cv2.imread(name12)
img_lines12 = cv2.imread(name12)
gray12 = cv2.cvtColor(img_lines12,cv2.COLOR_BGR2GRAY)
edges12 = cv2.Canny(gray12,50,150,apertureSize = 3)
lines12 = cv2.HoughLines(edges12,1,np.pi/180,200)
for line in lines12:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    if (x2-x1)!=0:
        if (y2-y1)/(x2-x1)!=0:
            cv2.line(img_lines12,(x1,y1),(x2,y2),(0,0,255),2)

# %%
plt.rcParams["figure.figsize"] = [12,9]
plt.imshow(img_lines12)
plt.savefig('../Diagrams/results/Disparity_benchmark/673_10_102_12_48_8_lines.png')
plt.show()
